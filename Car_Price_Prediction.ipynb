# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split

# %%
pwd
# Out:
# 'C:\\Users\\ADMIN'

# %%
df = pd.read_csv('car_data.csv')

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.shape
# Out:
# (301, 9)

# %%
col = df.columns

# %%
print(df.Seller_Type.unique())
print(df.Transmission.unique())
print(df.Owner.unique())
# Out:
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
## check missing values or null values
df.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
import datetime

# %%
df.corr()
# Out:
#                    Year  Selling_Price  Present_Price  Kms_Driven     Owner
# Year           1.000000       0.236141      -0.047584   -0.524342 -0.182104
# Selling_Price  0.236141       1.000000       0.878983    0.029187 -0.088344
# Present_Price -0.047584       0.878983       1.000000    0.203647  0.008057
# Kms_Driven    -0.524342       0.029187       0.203647    1.000000  0.089216
# Owner         -0.182104      -0.088344       0.008057    0.089216  1.000000

# %%
final_df = df[['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']]

# %%
final_df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
final_df['Current_Year'] = 2021

# %%
final_df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year
# 0       Manual      0          2021
# 1       Manual      0          2021
# 2       Manual      0          2021
# 3       Manual      0          2021
# 4       Manual      0          2021

# %%
final_df['no._year'] = final_df['Current_Year'] - final_df['Year']

# %%
final_df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year  no._year
# 0       Manual      0          2021         7
# 1       Manual      0          2021         8
# 2       Manual      0          2021         4
# 3       Manual      0          2021        10
# 4       Manual      0          2021         7

# %%
final_df.drop(['Year'], axis=1, inplace=True)

# %%
final_df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year  no._year
# 0       Manual      0          2021         7
# 1       Manual      0          2021         8
# 2       Manual      0          2021         4
# 3       Manual      0          2021        10
# 4       Manual      0          2021         7

# %%
final_df.drop(['Current_Year'], axis=1, inplace=True)

# %%
final_df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  no._year
# 0       Manual      0         7
# 1       Manual      0         8
# 2       Manual      0         4
# 3       Manual      0        10
# 4       Manual      0         7

# %%
final_df = pd.get_dummies(final_df, drop_first=True)

# %%
final_df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  no._year  \
# 0           3.35           5.59       27000      0         7
# 1           4.75           9.54       43000      0         8
# 2           7.25           9.85        6900      0         4
# 3           2.85           4.15        5200      0        10
# 4           4.60           6.87       42450      0         7
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
import seaborn as sns

# %%
sns.pairplot(final_df)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
corrmat = final_df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(7, 7))
g = sns.heatmap(final_df[top_corr_features].corr(), annot=True, cmap="RdYlGn")

# %%
# independent features and dependent features
X = final_df.iloc[:, 1:]
y = final_df.iloc[:, 0]

# %%
X.head()
# Out:
#    Present_Price  Kms_Driven  Owner  no._year  Fuel_Type_Diesel  \
# 0           5.59       27000      0         7                 0
# 1           9.54       43000      0         8                 1
# 2           9.85        6900      0         4                 0
# 3           4.15        5200      0        10                 0
# 4           6.87       42450      0         7                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20,random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (240, 8)
# (61, 8)

# %% [raw]
# Extra Trees Regressor

# %%
# Model Building
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,accuracy_score
from sklearn.ensemble import ExtraTreesRegressor
etr = ExtraTreesRegressor()

# Training Model
etr.fit(X_train,y_train)

# Model Summary
y_pred_etr = etr.predict(X_test)

r_squared = r2_score(y_test,y_pred_etr)
rmse = np.sqrt(mean_squared_error(y_test,y_pred_etr))
print("R_squared of Extra trees regressor:",r_squared)
print("RMSE :",rmse)
# Out:
# R_squared of Extra trees regressor: 0.9740887042144464
# RMSE : 0.7725812864018657

# %%
from sklearn import metrics #import r2_score,mean_squared_error,mean_absolute_error,accuracy_score

# %%
print('MAE:', metrics.mean_absolute_error(y_test, y_pred_etr))
print('MSE:', metrics.mean_squared_error(y_test, y_pred_etr))
# Out:
# MAE: 0.48587377049180386
# MSE: 0.5968818440983618

# %%
accuracy_test = etr.score(X_test, y_test)*100
print("Accuracy on test data:",accuracy_test)  #r2 score
# Out:
# Accuracy on test data: 97.40887042144463

# %%
# fitting the size of the plot
plt.figure(figsize=(10, 6))

# plotting the graphs
plt.plot([i for i in range(len(y_test))],y_test, color = 'green',label="actual values")
plt.plot([i for i in range(len(y_test))],y_pred_etr, color='red', label="Predicted values")

# showing the plotting
plt.legend()
plt.show()

# %%
etr.get_params()
# Out:
# {'bootstrap': False,
#  'ccp_alpha': 0.0,
#  'criterion': 'mse',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
etr.feature_importances_
# Out:
# array([0.41002295, 0.04087702, 0.00066138, 0.06747379, 0.2421093 ,
#        0.00633184, 0.10833987, 0.12418385])

# %%
feature_importances = pd.Series(etr.feature_importances_, index=X.columns)
# feature_importances.nlargest(5).plot(kind='barh')
feature_importances.plot(kind='barh')
plt.show()

# %%
print(feature_importances.sort_values(ascending=False))
# Out:
# Present_Price             0.410023
# Fuel_Type_Diesel          0.242109
# Transmission_Manual       0.124184
# Seller_Type_Individual    0.108340
# no._year                  0.067474
# Kms_Driven                0.040877
# Fuel_Type_Petrol          0.006332
# Owner                     0.000661
# dtype: float64

# %% [raw]
# Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=100)

# %% [markdown]
# ## Hyperparameters

# %%
# Randomized Search CV

## Number of trees in ramdom forest
n_estimators = [int(x) for x in np.linspace(start=100, stop=1200, num=12)]
## Number of features to consider at every split
max_features = ['auto', 'sqrt']
## Maximum number of level in tree
max_depth = [int(x) for x in np.linspace(5, 30, num=6)]
## Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
## Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
## it helps us to find out the best parameters
from sklearn.model_selection import RandomizedSearchCV

# %%
## create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}
print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf_random = RandomizedSearchCV(estimator=regressor, param_distributions=random_grid, scoring='neg_mean_squared_error',
                               n_iter=10, cv=5, verbose=2, random_state=42, n_jobs=1)

# %%
rf_random.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   1.9s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   1.8s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   1.8s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# ...

# %%
pred = rf_random.predict(X_test)

# %%
regressor.fit(X_train,y_train)   #training the model
y_pred_reg=regressor.predict(X_test)

# %%
print(y_pred_reg)
# Out:
# [ 0.4509 10.6498  4.987   0.219   7.7188  6.511   1.1192  0.5979  0.4784
#   6.825   7.9253  1.0897  8.2501  0.4527  5.394   2.697   1.1706 13.8626
#   0.4778  1.5395  0.3568  8.0694  4.744   2.757   0.5129  3.484   5.3585
#   3.111   1.2117  1.1683  0.4373 10.1125  0.4723  2.5575  7.7764  4.241
#   6.3754  5.8444  2.6215  6.547   4.0093  3.4293  5.0455  0.5649  6.427
#   0.7992  8.604   7.63    2.984   3.5715  4.9935  1.512  22.2256 20.5596
#   6.571  11.0395  5.12    9.1711  2.625   6.9559  0.2444]

# %%
r2_score(y_test,y_pred_reg)*100
# Out:
# 95.9662265406302

# %%
accuracy_test = regressor.score(X_test, y_test)*100
print("Accuracy on test data:",accuracy_test)  #r2 score
# Out:
# Accuracy on test data: 95.9662265406302

# %%
print("MAE: ",(metrics.mean_absolute_error(y_test,pred)))
print("MSE: ",(metrics.mean_squared_error(y_test,pred)))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,y_pred_reg)))
# Out:
# MAE:  0.6122736065573735
# MSE:  1.2607675930311455
# RMSE: 0.9639519150819523

# %%
# fitting the size of the plot
plt.figure(figsize=(5, 5))

# plotting the graphs
plt.plot([i for i in range(len(y_test))],y_test, color = 'green',label="actual values")
plt.plot([i for i in range(len(y_test))],y_pred_reg, color='red', label="Predicted values")

# showing the plotting
plt.legend()
plt.show()
